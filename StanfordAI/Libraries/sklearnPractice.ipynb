# %%
#https://medium.com/@julie.yin/understanding-the-data-splitting-functions-in-scikit-learn-9ae4046fbd26
#https://contactsunny.medium.com/linear-regression-in-python-using-scikit-learn-f0f7b125a204

import numpy 
import matplotlib.pyplot as plot
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('./data/salaryData.csv')

# %%
x = dataset.iloc[:, :-1] #x array
y = dataset.iloc[:,1] #y array
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 1/3, random_state = 0)
linearRegressor = LinearRegression()
linearRegressor.fit(xTrain,yTrain) #this method training using the
yPrediction = linearRegressor.predict(xTest)#testing the dataset you have

# %%
#creation of the training data set
plot.scatter(xTrain,yTrain, color = 'red') #plotting the actual values
plot.plot(xTrain, linearRegressor.predict(xTrain), color = 'blue') #plot of the test set
plot.title('Salary vs Expereince (Training Set)')
plot.xlabel('Years of Experience')
plot.ylabel('Salary')
plot.show()

# %%
#creation of the test set
plot.scatter(xTest,yTest, color= 'red')
plot.plot(xTrain, linearRegressor.predict(xTrain), color = 'blue')
plot.title('Salary vs Experience (Test Set)')
plot.xlabel('Years of Experience')
plot.ylabel('Salaries')
plot.show()
